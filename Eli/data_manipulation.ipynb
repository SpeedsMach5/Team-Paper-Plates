# %%
import pandas as pd
import sqlalchemy
from pathlib import Path

# %%
path = Path("../Paperplate/database_file.db")

# %%
connectiong_string = f"sqlite:///{path}"
engine = sqlalchemy.create_engine(connectiong_string)
engine.table_names()
# Out:
# /var/folders/bk/z2_y916x5gx26_4vt2c_99zh0000gn/T/ipykernel_34448/1266115083.py:3: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   engine.table_names()
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/opt/anaconda3/envs/dev/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    3249         try:
# -> 3250             return fn()
#    3251         except dialect.dbapi.Error as e:
#
# ~/opt/anaconda3/envs/dev/lib/python3.9/site-packages/sqlalchemy/pool/base.py in connect(self)
#     309         """
# --> 310         return _ConnectionFairy._checkout(self)
#     311
#
# ~/opt/anaconda3/envs/dev/lib/python3.9/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
# ...

# %%
pd.read_sql_table("Texas License Plates",con=engine)
# Out:
#        index First Name   Last Name Social Security License Plate  \
# 0          0        Dan   Davenport     461-97-2773       DJG 154
# 1          1       Beth  Williamson     644-07-6647       UDN 513
# 2          2      Peggy       Clark     161-78-8795       FLR 034
# 3          3      Jason        Wang     145-90-7173       IYB 988
# 4          4  Stephanie      Rivera     258-20-9406       WZB 033
# ...      ...        ...         ...             ...           ...
# 99995  99995      Debra      Nguyen     368-75-6545       UDQ 730
# 99996  99996       Adam       Walls     813-14-8519       QUB 100
# 99997  99997       John       Doyle     541-18-7859       QNN 906
# 99998  99998   Kristina     Anthony     670-06-3450       LZH 779
# 99999  99999      Jason       Black     017-82-4670       YBH 968
#
#               VIN Number License Plate Status  \
# 0      3KVLS58NSLC361691      Not in Database
# 1      2TIJE70HFGE505470            Temporary
# ...
