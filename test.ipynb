# %%
import qrcode
from faker import Faker
from faker_vehicle import VehicleProvider
import pandas as pd
from faker.providers import automotive
import random
import streamlit as st
import web3 as Web3
import pandas as pd
import path as Path
import sqlalchemy as db
from sqlalchemy import create_engine, MetaData, Table

# %%
engine = create_engine('sqlite:///database_file.db')
connection = engine.connect()

# %%
pd.read_sql_table("Texas License Plates", con=engine)
# Out:
#        index First Name  Last Name Social Security License Plate  \
# 0          0      Corey       Webb     220-69-3767       RNP 640
# 1          1   Michelle  Hendricks     586-56-5060       WAE 607
# 2          2     Harold   Griffith     297-22-6980       THA 742
# 3          3      James        Lee     523-81-1618       DNB 853
# 4          4       Tina     Foster     259-12-8318       JQN 937
# ...      ...        ...        ...             ...           ...
# 99995  99995    Annette     Guzman     451-77-8451       OHO 192
# 99996  99996   Courtney    Acevedo     077-76-5592       RCV 986
# 99997  99997      Maria     Miller     093-74-3499       LYN 689
# 99998  99998  Christian       Berg     140-69-4643       XDO 475
# 99999  99999  Elizabeth     Harris     260-73-6577       EEZ 914
#
#               VIN Number License Plate Status                      Address 1  \
# 0      7JAID36TFVM191606              Pending             260 Wilson Landing
# 1      7YCYG73WVTF509653            Permanent          597 Victoria Villages
# 2      8FAYQ91BKRA587472      Not in Database  1786 Anderson Unions Apt. 995
# 3      1XNFX59BUZC399801              Pending             4402 Dwayne Square
# 4      1ALOM88BGOL465271              Pending     410 Reynolds Road Apt. 480
# ...                  ...                  ...                            ...
# 99995  3DWPQ86RLII394865      Not in Database              224 Griffin Ports
# 99996  3SPKU78GOVY732629              Pending               347 Hale Gateway
# 99997  3DRCV29LEDF000953              Pending  4590 Murillo Shoals Suite 703
# 99998  0MWMK69TRAM937671            Temporary             037 Chambers Knoll
# 99999  4ULEH51VPJY512951              Pending               63386 Todd Ranch
#
#                    City Postal Code  State        Country  Year        Make  \
# 0      Port Janicemouth       79350  Texas  United States  2010      Toyota
# 1           East George       76394  Texas  United States  2016     Hyundai
# 2      South Alexandria       77859  Texas  United States  2001        Audi
# 3           Nathanshire       77867  Texas  United States  1994    Plymouth
# 4           Lake Thomas       78786  Texas  United States  2016   Chevrolet
# ...                 ...         ...    ...            ...   ...         ...
# 99995        New Thomas       77338  Texas  United States  1997       Buick
# 99996     Zimmermanside       76046  Texas  United States  2003  Mitsubishi
# 99997          Bethberg       79496  Texas  United States  2008      Toyota
# 99998       Taylormouth       78554  Texas  United States  2019        Jeep
# 99999        Stuartstad       79052  Texas  United States  2003        Ford
#
#                        Model            Category
# 0                 Highlander                 SUV
# 1           Tucson Fuel Cell                 SUV
# 2                         S4        Wagon, Sedan
# 3                   Sundance           Hatchback
# 4                      Sonic    Sedan, Hatchback
# ...                      ...                 ...
# 99995                  Regal               Sedan
# 99996                Eclipse  Coupe, Convertible
# 99997             Highlander                 SUV
# 99998     Wrangler Unlimited                 SUV
# 99999  E350 Super Duty Cargo         Van/Minivan
#
# [100000 rows x 16 columns]
